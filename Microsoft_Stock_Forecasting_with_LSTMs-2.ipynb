# %%
# dataset @ https://finance.yahoo.com/quote/MSFT/history/

# If you want the exact same dataset as the YouTube video,
# use this link: https://drive.google.com/file/d/1WLm1AEYgU28Nk4lY4zNkGPSctdImbhJI/view?usp=sharing

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9480  2023-10-24  331.299988  331.839996  327.600006  330.529999  330.529999
# 9481  2023-10-25  345.019989  346.200012  337.619995  340.670013  340.670013
# 9482  2023-10-26  340.540009  341.630005  326.940002  327.890015  327.890015
# 9483  2023-10-27  330.429993  336.720001  328.399994  329.809998  329.809998
# 9484  2023-10-30  333.410004  339.450012  331.829987  337.309998  337.309998
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9480    31153600
# 9481    55053800
# 9482    37828500
# 9483    29835200
# 9484    22811600
#
# [9485 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9480  2023-10-24  330.529999
# 9481  2023-10-25  340.670013
# 9482  2023-10-26  327.890015
# 9483  2023-10-27  329.809998
# 9484  2023-10-30  337.309998
#
# [9485 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9480    2023-10-24
# 9481    2023-10-25
# 9482    2023-10-26
# 9483    2023-10-27
# 9484    2023-10-30
# Name: Date, Length: 9485, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9480  2023-10-24  330.529999
# 9481  2023-10-25  340.670013
# 9482  2023-10-26  327.890015
# 9483  2023-10-27  329.809998
# 9484  2023-10-30  337.309998
#
# [9485 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /var/folders/cw/4h21z1z97nj4kpz6xtttv1jr0000gn/T/ipykernel_56942/2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9480   2023-10-24
# 9481   2023-10-25
# 9482   2023-10-26
# 9483   2023-10-27
# 9484   2023-10-30
# Name: Date, Length: 9485, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-24  330.529999
# 2023-10-25  340.670013
# 2023-10-26  327.890015
# 2023-10-27  329.809998
# 2023-10-30  337.309998
#
# [9485 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
# !pip install tensorflow
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/protobuf-4.24.4-py3.11.egg-info due to invalid metadata entry 'name'
# Requirement already satisfied: tensorflow in /opt/homebrew/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/shreyamahajan/Library/Python/3.11/lib/python/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/homebrew/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.2)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/protobuf-4.24.4-py3.11.egg-info due to invalid metadata entry 'name'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers


model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 7/7 [==============================] - 1s 33ms/step - loss: 84829.3516 - mean_absolute_error: 289.5147 - val_loss: 92423.5625 - val_mean_absolute_error: 303.9253
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 84461.9531 - mean_absolute_error: 288.8792 - val_loss: 92109.6328 - val_mean_absolute_error: 303.4084
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 84185.9766 - mean_absolute_error: 288.4016 - val_loss: 91840.0703 - val_mean_absolute_error: 302.9639
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 83905.8984 - mean_absolute_error: 287.9162 - val_loss: 91489.5234 - val_mean_absolute_error: 302.3848
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 83528.9141 - mean_absolute_error: 287.2625 - val_loss: 91008.5703 - val_mean_absolute_error: 301.5884
# Epoch 6/100
# 7/7 [==============================] - 0s 5ms/step - loss: 83001.6797 - mean_absolute_error: 286.3445 - val_loss: 90289.4297 - val_mean_absolute_error: 300.3938
# Epoch 7/100
# 7/7 [==============================] - 0s 4ms/step - loss: 82206.0859 - mean_absolute_error: 284.9491 - val_loss: 89339.8516 - val_mean_absolute_error: 298.8091
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 81279.8828 - mean_absolute_error: 283.3195 - val_loss: 88300.8281 - val_mean_absolute_error: 297.0654
# Epoch 9/100
# 7/7 [==============================] - 0s 5ms/step - loss: 80227.2969 - mean_absolute_error: 281.4466 - val_loss: 87031.2266 - val_mean_absolute_error: 294.9207
# Epoch 10/100
# 7/7 [==============================] - 0s 4ms/step - loss: 78937.5078 - mean_absolute_error: 279.1540 - val_loss: 85554.9219 - val_mean_absolute_error: 292.4071
# Epoch 11/100
# 7/7 [==============================] - 0s 3ms/step - loss: 77366.7656 - mean_absolute_error: 276.3280 - val_loss: 83472.7578 - val_mean_absolute_error: 288.8247
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 75207.5000 - mean_absolute_error: 272.3996 - val_loss: 80962.8438 - val_mean_absolute_error: 284.4465
# Epoch 13/100
# 7/7 [==============================] - 0s 3ms/step - loss: 72663.5547 - mean_absolute_error: 267.6984 - val_loss: 78160.5312 - val_mean_absolute_error: 279.4773
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 69950.8594 - mean_absolute_error: 262.5719 - val_loss: 74941.3828 - val_mean_absolute_error: 273.6571
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 66510.9141 - mean_absolute_error: 255.9486 - val_loss: 70992.0547 - val_mean_absolute_error: 266.3439
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 62873.3789 - mean_absolute_error: 248.6987 - val_loss: 66982.5078 - val_mean_absolute_error: 258.7073
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 58801.8398 - mean_absolute_error: 240.4121 - val_loss: 62072.1758 - val_mean_absolute_error: 249.0362
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 53701.3477 - mean_absolute_error: 229.4796 - val_loss: 56262.0000 - val_mean_absolute_error: 237.0844
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 48429.3477 - mean_absolute_error: 217.6846 - val_loss: 50585.9805 - val_mean_absolute_error: 224.7955
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 43101.3828 - mean_absolute_error: 205.1498 - val_loss: 44958.8711 - val_mean_absolute_error: 211.9101
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 37815.2773 - mean_absolute_error: 191.7215 - val_loss: 38891.6758 - val_mean_absolute_error: 197.0742
# Epoch 22/100
# 7/7 [==============================] - 0s 3ms/step - loss: 31650.0547 - mean_absolute_error: 174.8748 - val_loss: 32024.8203 - val_mean_absolute_error: 178.8068
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 25897.2734 - mean_absolute_error: 157.6874 - val_loss: 26341.9844 - val_mean_absolute_error: 162.1389
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 20874.5273 - mean_absolute_error: 140.8049 - val_loss: 21062.7598 - val_mean_absolute_error: 144.9475
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 16264.3770 - mean_absolute_error: 123.4049 - val_loss: 16170.7021 - val_mean_absolute_error: 126.9548
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12041.3350 - mean_absolute_error: 104.8529 - val_loss: 11586.3535 - val_mean_absolute_error: 107.3929
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 8347.1250 - mean_absolute_error: 85.4483 - val_loss: 8017.1074 - val_mean_absolute_error: 89.2420
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 5642.4131 - mean_absolute_error: 67.9184 - val_loss: 5301.0439 - val_mean_absolute_error: 72.4436
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3706.0239 - mean_absolute_error: 51.8545 - val_loss: 3325.3425 - val_mean_absolute_error: 57.2044
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2426.5488 - mean_absolute_error: 39.8747 - val_loss: 1947.3339 - val_mean_absolute_error: 43.5243
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1625.3734 - mean_absolute_error: 33.1361 - val_loss: 1098.3174 - val_mean_absolute_error: 32.3319
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1214.9268 - mean_absolute_error: 29.3084 - val_loss: 627.3219 - val_mean_absolute_error: 23.9657
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1060.8022 - mean_absolute_error: 27.5998 - val_loss: 380.0161 - val_mean_absolute_error: 18.0845
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1023.8658 - mean_absolute_error: 27.0490 - val_loss: 262.5544 - val_mean_absolute_error: 14.5768
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1011.5892 - mean_absolute_error: 26.9010 - val_loss: 222.8674 - val_mean_absolute_error: 13.2497
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1013.5120 - mean_absolute_error: 26.9144 - val_loss: 215.9036 - val_mean_absolute_error: 13.0013
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1014.3918 - mean_absolute_error: 26.9284 - val_loss: 220.1817 - val_mean_absolute_error: 13.1545
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1012.3667 - mean_absolute_error: 26.9035 - val_loss: 244.0241 - val_mean_absolute_error: 13.9744
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.6558 - mean_absolute_error: 26.8652 - val_loss: 259.8427 - val_mean_absolute_error: 14.4904
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.8665 - mean_absolute_error: 26.8693 - val_loss: 268.2500 - val_mean_absolute_error: 14.7566
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.1841 - mean_absolute_error: 26.8612 - val_loss: 271.3711 - val_mean_absolute_error: 14.8541
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.0224 - mean_absolute_error: 26.8575 - val_loss: 266.6558 - val_mean_absolute_error: 14.7065
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.1815 - mean_absolute_error: 26.8646 - val_loss: 252.7144 - val_mean_absolute_error: 14.2604
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.5787 - mean_absolute_error: 26.8752 - val_loss: 252.9143 - val_mean_absolute_error: 14.2669
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.4794 - mean_absolute_error: 26.8707 - val_loss: 260.6472 - val_mean_absolute_error: 14.5161
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.4395 - mean_absolute_error: 26.8686 - val_loss: 255.4148 - val_mean_absolute_error: 14.3480
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.3743 - mean_absolute_error: 26.8713 - val_loss: 253.6379 - val_mean_absolute_error: 14.2904
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.3300 - mean_absolute_error: 26.8724 - val_loss: 257.6994 - val_mean_absolute_error: 14.4217
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.3498 - mean_absolute_error: 26.8649 - val_loss: 266.2059 - val_mean_absolute_error: 14.6924
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1009.9656 - mean_absolute_error: 26.8575 - val_loss: 262.2727 - val_mean_absolute_error: 14.5679
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.3065 - mean_absolute_error: 26.8668 - val_loss: 260.2820 - val_mean_absolute_error: 14.5045
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1010.7411 - mean_absolute_error: 26.8746 - val_loss: 259.5797 - val_mean_absolute_error: 14.4820
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1009.7503 - mean_absolute_error: 26.8614 - val_loss: 268.7249 - val_mean_absolute_error: 14.7716
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1008.1100 - mean_absolute_error: 26.8339 - val_loss: 285.2570 - val_mean_absolute_error: 15.2861
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 976.0659 - mean_absolute_error: 26.3243 - val_loss: 485.3213 - val_mean_absolute_error: 20.8806
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 929.6343 - mean_absolute_error: 25.7242 - val_loss: 262.0491 - val_mean_absolute_error: 14.5920
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 942.2258 - mean_absolute_error: 25.9233 - val_loss: 349.8841 - val_mean_absolute_error: 17.3437
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 887.4706 - mean_absolute_error: 25.1815 - val_loss: 295.4368 - val_mean_absolute_error: 15.7112
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 858.9167 - mean_absolute_error: 24.7404 - val_loss: 283.9281 - val_mean_absolute_error: 15.3750
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 830.2931 - mean_absolute_error: 24.2426 - val_loss: 361.2013 - val_mean_absolute_error: 17.7599
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 801.5695 - mean_absolute_error: 23.9710 - val_loss: 263.7137 - val_mean_absolute_error: 14.7592
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 778.2887 - mean_absolute_error: 23.5821 - val_loss: 236.6098 - val_mean_absolute_error: 13.9022
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 748.2222 - mean_absolute_error: 23.1254 - val_loss: 403.0745 - val_mean_absolute_error: 18.9648
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 724.4420 - mean_absolute_error: 22.7267 - val_loss: 138.8454 - val_mean_absolute_error: 10.0991
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 706.7579 - mean_absolute_error: 22.2898 - val_loss: 196.4664 - val_mean_absolute_error: 12.5509
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 656.0577 - mean_absolute_error: 21.5493 - val_loss: 275.4370 - val_mean_absolute_error: 15.3046
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 617.2173 - mean_absolute_error: 20.8311 - val_loss: 105.2963 - val_mean_absolute_error: 8.5172
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 614.2255 - mean_absolute_error: 20.8368 - val_loss: 187.7836 - val_mean_absolute_error: 12.2919
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 527.8300 - mean_absolute_error: 19.3660 - val_loss: 350.1978 - val_mean_absolute_error: 17.6741
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 523.1597 - mean_absolute_error: 19.0477 - val_loss: 67.7179 - val_mean_absolute_error: 6.5998
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 453.1075 - mean_absolute_error: 17.6242 - val_loss: 269.6316 - val_mean_absolute_error: 15.3254
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 363.6530 - mean_absolute_error: 15.6773 - val_loss: 122.1344 - val_mean_absolute_error: 9.5887
# Epoch 73/100
# 7/7 [==============================] - 0s 5ms/step - loss: 298.5953 - mean_absolute_error: 14.1019 - val_loss: 173.5467 - val_mean_absolute_error: 11.8579
# Epoch 74/100
# 7/7 [==============================] - 0s 4ms/step - loss: 287.2303 - mean_absolute_error: 14.0995 - val_loss: 165.4621 - val_mean_absolute_error: 11.5543
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 233.3159 - mean_absolute_error: 12.4113 - val_loss: 104.3283 - val_mean_absolute_error: 8.7671
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 196.5074 - mean_absolute_error: 11.1684 - val_loss: 110.6372 - val_mean_absolute_error: 9.0690
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 173.5005 - mean_absolute_error: 10.3184 - val_loss: 126.8502 - val_mean_absolute_error: 9.8399
# Epoch 78/100
# 7/7 [==============================] - 0s 5ms/step - loss: 145.4818 - mean_absolute_error: 9.3782 - val_loss: 52.4662 - val_mean_absolute_error: 5.9513
# Epoch 79/100
# 7/7 [==============================] - 0s 4ms/step - loss: 117.6090 - mean_absolute_error: 8.1671 - val_loss: 51.1068 - val_mean_absolute_error: 5.9054
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 99.1300 - mean_absolute_error: 7.4766 - val_loss: 32.0032 - val_mean_absolute_error: 4.9683
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 82.6879 - mean_absolute_error: 6.6973 - val_loss: 30.5959 - val_mean_absolute_error: 4.8908
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 72.0829 - mean_absolute_error: 6.1458 - val_loss: 34.9191 - val_mean_absolute_error: 4.8920
# Epoch 83/100
# 7/7 [==============================] - 0s 3ms/step - loss: 64.6022 - mean_absolute_error: 6.1752 - val_loss: 40.4437 - val_mean_absolute_error: 5.0987
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 57.6955 - mean_absolute_error: 5.6609 - val_loss: 30.3177 - val_mean_absolute_error: 4.8395
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 48.5508 - mean_absolute_error: 5.1166 - val_loss: 47.5038 - val_mean_absolute_error: 5.3911
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 48.0426 - mean_absolute_error: 5.5197 - val_loss: 47.0147 - val_mean_absolute_error: 5.3802
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 39.2139 - mean_absolute_error: 4.7206 - val_loss: 31.3432 - val_mean_absolute_error: 4.8146
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 38.0244 - mean_absolute_error: 4.6477 - val_loss: 35.6680 - val_mean_absolute_error: 4.9057
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 36.4415 - mean_absolute_error: 4.7231 - val_loss: 48.0762 - val_mean_absolute_error: 5.5044
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 30.1766 - mean_absolute_error: 4.1944 - val_loss: 65.9697 - val_mean_absolute_error: 6.4333
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 29.5177 - mean_absolute_error: 4.2846 - val_loss: 49.3276 - val_mean_absolute_error: 5.5921
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 28.7509 - mean_absolute_error: 4.1944 - val_loss: 38.4568 - val_mean_absolute_error: 5.3024
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 55.7952 - mean_absolute_error: 6.1278 - val_loss: 80.6739 - val_mean_absolute_error: 7.3309
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 32.5054 - mean_absolute_error: 4.5486 - val_loss: 117.1658 - val_mean_absolute_error: 9.3050
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 42.0212 - mean_absolute_error: 5.3897 - val_loss: 72.7129 - val_mean_absolute_error: 6.8297
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 26.7650 - mean_absolute_error: 4.0358 - val_loss: 34.3740 - val_mean_absolute_error: 4.9817
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 31.5034 - mean_absolute_error: 4.7665 - val_loss: 68.5300 - val_mean_absolute_error: 7.0009
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 60.6828 - mean_absolute_error: 6.5516 - val_loss: 41.0340 - val_mean_absolute_error: 5.4923
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 37.2015 - mean_absolute_error: 5.0465 - val_loss: 40.9378 - val_mean_absolute_error: 5.1085
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 29.3364 - mean_absolute_error: 4.3791 - val_loss: 42.4831 - val_mean_absolute_error: 5.2248

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 692us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np

y_pred = model.predict(X_test)


mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Mean Absolute Percentage Error (MAPE): 3.16%
# Accuracy: 96.84%

# %%
import pickle
with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %%
from tensorflow import keras

# Save the model to an HDF5 file
model.save("model.h5")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow import keras

# Load the model from the HDF5 file
model = keras.models.load_model("model.h5")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
